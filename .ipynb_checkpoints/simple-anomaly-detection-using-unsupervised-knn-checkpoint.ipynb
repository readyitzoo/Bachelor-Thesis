# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Simple Anomaly Detection using Unsupervised KNN
# </h1>
# </div>
# </div>

# %% [markdown]
# <img src="https://ei.marketwatch.com/Multimedia/2017/05/22/Photos/ZH/MW-FM980_netfli_20170522210252_ZH.jpg?uuid=8bee2706-3f53-11e7-8476-9c8e992d421e" alt="">

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Import Libraries
# </h1>
# </div>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Read Data
# </h1>
# </div>
# </div>

# %%
df = pd.read_csv("NFLX_1.csv")
df = df.iloc[3500:,:]
df['Date']=pd.to_datetime(df['Date'])
# df1 = df

# %%
fig, ax = plt.subplots(figsize=(20,8))
plt.plot(df["Date"], df["Open"], color='Red')
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Opening Price in USD', fontsize='11')
plt.title('Netflix Stock Prices (April 13th 2018 ~)')
plt.grid()
plt.show()

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Data Pre-processing
# </h1>
# </div>
# </div>

# %%
df = df.drop(columns=['High','Low','Close','Volume','Adj Close'])
df.head(10)
# Out:
#            Date       Open
# 3500 2016-04-19  99.489998
# 3501 2016-04-20  94.339996
# 3502 2016-04-21  97.309998
# 3503 2016-04-22  94.849998
# 3504 2016-04-25  95.699997
# 3505 2016-04-26  93.500000
# 3506 2016-04-27  92.180000
# 3507 2016-04-28  91.500000
# 3508 2016-04-29  90.500000
# 3509 2016-05-02  90.410004

# %%
for i in range(len(df)):
    df['Date'][i+3500] = i
df
# Out:
# C:\Users\Ricardo Milos\AppData\Local\Temp\ipykernel_21028\3641605131.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'][i+3500] = i
#       Date        Open
# 3500     0   99.489998
# 3501     1   94.339996
# 3502     2   97.309998
# 3503     3   94.849998
# 3504     4   95.699997
# ...    ...         ...
# 5039  1539  193.190002
# 5040  1540  196.179993
# 5041  1541  198.699997
# 5042  1542  192.020004
# 5043  1543  200.139999
#
# [1544 rows x 2 columns]

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Unsupervised Learning : KNN
# </h1>
# </div>
# </div>

# %% [markdown]
# <img src="https://miro.medium.com/max/778/1*z8PiWePLH9P82hJ2P0N0Jg.png" alt="">

# %% [markdown]
# **KNN is a supervised learning-based algorithm.
# However, using KNN's distance calculation method can also be used as an unsupervised learning method.**
#
# **In this work, we will use Scikit-Learn's NearestNeighbors, which we can use it for unsupervised learning**

# %% [markdown]
# ### sklearn.neighbors.NearestNeighbors
# ```
# class sklearn.neighbors.NearestNeighbors(*, n_neighbors=5, radius=1.0, algorithm='auto', leaf_size=30, metric='minkowski', p=2, metric_params=None, n_jobs=None)
# ```
# - n_neighbors : int, default=5 (Number of neighbors to use by default for kneighbors queries.)
# - radius : float, default=1.0 (Range of parameter space to use by default for radius_neighbors queries.)
# - algorithm : {‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’}, default=’auto’ (Algorithm used to compute the nearest neighbors)
# - metric : str or callable, default=’minkowski’ (the distance metric to use for the tree.)
# - p : int, default=2 (Parameter for the Minkowski metric from sklearn.metrics.pairwise.pairwise_distances. When p = 1, this is equivalent to using manhattan_distance (l1), and euclidean_distance (l2) for p = 2.)

# %%
# create model
nbrs = NearestNeighbors(n_neighbors = 10)
# fit model
nbrs.fit(df)
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
# distances and indexes of k-neaighbors from model outputs
distances, indexes = nbrs.kneighbors(df)
# plot
plt.figure(figsize=(15, 7))
plt.plot(distances.mean(axis =1))

# %%
distances = pd.DataFrame(distances)
distances_mean = distances.mean(axis =1)
distances_mean
# Out:
# 0        7.160294
# 1        4.680722
# 2        4.896900
# 3        3.729542
# 4        3.787862
#           ...
# 1539     6.194330
# 1540     7.029236
# 1541     8.495861
# 1542     7.150375
# 1543    10.210480
# Length: 1544, dtype: float64

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Get Abnormal Points
# </h1>
# </div>
# </div>

# %% [markdown]
# **Set thresholds with reference to statistics.**

# %%
distances_mean.describe()
# Out:
# count    1544.000000
# mean        6.478960
# std         3.419586
# min         2.563133
# 25%         4.137472
# 50%         5.835106
# 75%         7.822248
# max        42.124776
# dtype: float64

# %% [markdown]
# Since 75th percentile is 7.82, we will set threshold into 10.0

# %%
th = 12.0
outlier_index = np.where(distances_mean > th)
outlier_index
# Out:
# (array([ 472,  493,  565,  566,  588,  589,  626,  630,  631,  639,  646,
#          654,  676,  677,  683,  684,  687,  824,  881,  978,  981,  982,
#          983,  984,  985,  986,  991, 1003, 1008, 1014, 1060, 1064, 1065,
#         1068, 1074, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1106, 1131,
#         1133, 1135, 1147, 1148, 1186, 1197, 1198, 1199, 1200, 1220, 1305,
#         1319, 1352, 1353, 1375, 1376, 1389, 1416, 1421, 1441, 1442, 1443,
#         1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1454, 1458, 1459,
#         1460, 1486, 1487, 1508, 1510, 1511, 1512, 1513, 1514, 1515, 1528],
#        dtype=int64),)

# %%
outlier_values = df.iloc[outlier_index]
outlier_values
# Out:
#       Date        Open
# 3972   472  302.850006
# 3993   493  273.630005
# 4065   565  346.950012
# 4066   566  381.239990
# 4088   588  319.010010
# ...    ...         ...
# 5012  1512  245.199997
# 5013  1513  220.000000
# 5014  1514  220.179993
# 5015  1515  213.809998
# 5028  1528  163.960007
#
# [88 rows x 2 columns]

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:crimson;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Visualize Abnormal Points
# </h1>
# </div>
# </div>

# %%
# plot data
plt.figure(figsize=(20, 7))
plt.plot(df["Date"], df["Open"], color = "b")
# plot outlier values
plt.scatter(outlier_values["Date"], outlier_values["Open"], color = "r")

# %% [markdown]
# **It can be seen that our KNN algorithm captures the soaring and plunging points of the stock graph quite well!**
